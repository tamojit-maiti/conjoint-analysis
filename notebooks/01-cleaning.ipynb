# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
# Import files
base_path = '../'
data_folder_name = 'data/raw/fresh-sip/'
survey_filename = 'Pre_Launch_Survey_Cleaned.csv'

# Input Data
survey_df = pd.read_csv(os.path.join(base_path, data_folder_name, survey_filename), index_col='Serial No')
survey_df
# Out:
#           What combination of ingredients present in a beverage are you more likely to buy?  \
# Serial No
# 1          Seasonal fruits such as mango, orange, grapes,...
# 2          Seasonal fruits such as mango, orange, grapes,...
# 3          Seasonal fruits such as mango, orange, grapes,...
# 4          Seasonal fruits such as mango, orange, grapes,...
# 5          Seasonal fruits such as mango, orange, grapes,...
# ...                                                      ...
# 106        Exotic Fruits such as kiwi, dragon fruit, blue...
# 107        Non seasonal fruits such as pineapple, apple, ...
# 108        Non seasonal fruits such as pineapple, apple, ...
# 109        Seasonal fruits such as mango, orange, grapes,...
# 110        Seasonal fruits such as mango, orange, grapes,...
#
#           What volume of beverage are you most likely to buy?  \
# Serial No
# 1                                                     500 ml
# 2                                                     350 ml
# 3                                           Less than 300 ml
# 4                                        Greater than 750 ml
# 5                                                     350 ml
# ...                                                      ...
# 106                                         Less than 300 ml
# 107                                         Less than 300 ml
# 108                                                   350 ml
# 109                                                   500 ml
# 110                                                   350 ml
#
#           At which price point are you most likely to buy a beverage?  \
# Serial No
# 1                                        Between ₹150 - ₹250
# 2                                        Between ₹150 - ₹250
# 3                                             Less than ₹150
# 4                                        Between ₹150 - ₹250
# 5                                             Less than ₹150
# ...                                                      ...
# 106                                      Between ₹150 - ₹250
# 107                                      Between ₹150 - ₹250
# 108                                           Less than ₹150
# 109                                           Less than ₹150
# 110                                      Between ₹150 - ₹250
#
#           Which beverage type appeals to you the most?  \
# Serial No
# 1                                   Cold pressed juice
# 2                                  Healthy detox juice
# 3                                   Cold pressed juice
# 4                                   Cold pressed juice
# 5                                   Cold pressed juice
# ...                                                ...
# 106              Fusion of two or more fruits and nuts
# 107              Fusion of two or more fruits and nuts
# 108                                 Cold pressed juice
# 109              Fusion of two or more fruits and nuts
# 110                                 Cold pressed juice
#
#           Which is your most preferred location to buy beverages?  \
# Serial No
# 1                                           Equal preference
# 2                                           Equal preference
# 3                                        Food Court in malls
# 4                                           Equal preference
# 5                                           Equal preference
# ...                                                      ...
# 106                                         Equal preference
# 107                                      Stand-alone outlets
# 108                                      Stand-alone outlets
# 109                                      Stand-alone outlets
# 110                                      Food Court in malls
#
#           Do you prefer to have juice during winters? If not, what is your preferred choice of drink during winters?
# Serial No
# 1                                                        NaN
# 2                                                        NaN
# 3                                                        NaN
# 4                                                        NaN
# 5                                                        NaN
# ...                                                      ...
# 106                                               No, coffee
# 107                                                      NaN
# 108                                                      NaN
# 109                                                      NaN
# 110                                                   Coffee
#
# [110 rows x 6 columns]

# %%
# Transform column names
survey_df.columns = ['ingredients','volume','price','beverage_type', 'location','response']
survey_df['response'] = 1

# %%
# Unique values per column
unique_vals = {}
columns = survey_df.columns
for col in survey_df.columns:
    unique_vals[col] = survey_df[col].unique().tolist()

# %%
# Convert to a choice based conjoint survey from a frequency based survey
def expand_survey(df : pd.DataFrame = survey_df):
    response_rows = []
    for index, row in survey_df.iterrows():
        row_value = row.tolist()
        response_rows.append(row_value)
        for col_index in range(5):
            column = columns[col_index]
            value = row_value[col_index]
            unique_col_vals = unique_vals[column].copy()
            try:
                unique_col_vals.remove(value) 
            except:
                continue
            
            melt_row_value = [row_value] * len(unique_col_vals)
            for duplicate_row_index in range(len(melt_row_value)):
                duplicate_row = melt_row_value[duplicate_row_index].copy()
                # set response equal to zero
                duplicate_row[-1] = 0
                # set new values to relevant column
                duplicate_row[col_index] = unique_col_vals[duplicate_row_index]
                response_rows.append(duplicate_row)
    
    return pd.DataFrame(response_rows, columns= survey_df.columns)

# %%
# Expanded Survey Dataset
expand_survey_df = expand_survey(df = survey_df)
expand_survey_df
# Out:
#                                             ingredients  volume  \
# 0     Seasonal fruits such as mango, orange, grapes,...  500 ml
# 1     Exotic Fruits such as kiwi, dragon fruit, blue...  500 ml
# 2     Non seasonal fruits such as pineapple, apple, ...  500 ml
# 3              Veggies such as carrot, cucumber, tomato  500 ml
# 4     Seasonal fruits such as mango, orange, grapes,...  350 ml
# ...                                                 ...     ...
# 1755  Seasonal fruits such as mango, orange, grapes,...  350 ml
# 1756  Seasonal fruits such as mango, orange, grapes,...  350 ml
# 1757  Seasonal fruits such as mango, orange, grapes,...  350 ml
# 1758  Seasonal fruits such as mango, orange, grapes,...  350 ml
# 1759  Seasonal fruits such as mango, orange, grapes,...  350 ml
#
#                     price                          beverage_type  \
# 0     Between ₹150 - ₹250                     Cold pressed juice
# 1     Between ₹150 - ₹250                     Cold pressed juice
# 2     Between ₹150 - ₹250                     Cold pressed juice
# 3     Between ₹150 - ₹250                     Cold pressed juice
# 4     Between ₹150 - ₹250                     Cold pressed juice
# ...                   ...                                    ...
# 1755  Between ₹150 - ₹250                              Mocktails
# 1756  Between ₹150 - ₹250         Dairy based lassi or smoothies
# 1757  Between ₹150 - ₹250  Fusion of two or more fruits and nuts
# 1758  Between ₹150 - ₹250                     Cold pressed juice
# 1759  Between ₹150 - ₹250                     Cold pressed juice
#
#                  location  response
# 0        Equal preference         1
# 1        Equal preference         0
# 2        Equal preference         0
# 3        Equal preference         0
# 4        Equal preference         0
# ...                   ...       ...
# 1755  Food Court in malls         0
# 1756  Food Court in malls         0
# 1757  Food Court in malls         0
# 1758     Equal preference         0
# 1759  Stand-alone outlets         0
#
# [1760 rows x 6 columns]

# %%
# Final Conjoint Dataset
conjoint_df = pd.get_dummies(expand_survey_df, prefix = expand_survey_df.columns[:-1])
conjoint_df
# Out:
#       response  \
# 0            1
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 1755         0
# 1756         0
# 1757         0
# 1758         0
# 1759         0
#
#       ingredients_Exotic Fruits such as kiwi, dragon fruit, blue berry  \
# 0                                                 False
# 1                                                  True
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 1755                                              False
# 1756                                              False
# 1757                                              False
# 1758                                              False
# 1759                                              False
#
#       ingredients_Non seasonal fruits such as pineapple, apple, banana, papaya  \
# 0                                                 False
# 1                                                 False
# 2                                                  True
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 1755                                              False
# 1756                                              False
# 1757                                              False
# 1758                                              False
# 1759                                              False
#
#       ingredients_Seasonal fruits such as mango, orange, grapes, watermelon  \
# 0                                                  True
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                  True
# ...                                                 ...
# 1755                                               True
# 1756                                               True
# 1757                                               True
# 1758                                               True
# 1759                                               True
#
#       ingredients_Veggies such as carrot, cucumber, tomato  volume_350 ml  \
# 0                                                 False             False
# 1                                                 False             False
# 2                                                 False             False
# 3                                                  True             False
# 4                                                 False              True
# ...                                                 ...               ...
# 1755                                              False              True
# 1756                                              False              True
# 1757                                              False              True
# 1758                                              False              True
# 1759                                              False              True
#
#       volume_500 ml  volume_Greater than 750 ml  volume_Less than 300 ml  \
# 0              True                       False                    False
# 1              True                       False                    False
# 2              True                       False                    False
# 3              True                       False                    False
# 4             False                       False                    False
# ...             ...                         ...                      ...
# 1755          False                       False                    False
# 1756          False                       False                    False
# 1757          False                       False                    False
# 1758          False                       False                    False
# 1759          False                       False                    False
#
#       price_Between ₹150 - ₹250  ...  price_Less than ₹150  \
# 0                          True  ...                 False
# 1                          True  ...                 False
# 2                          True  ...                 False
# 3                          True  ...                 False
# 4                          True  ...                 False
# ...                         ...  ...                   ...
# 1755                       True  ...                 False
# 1756                       True  ...                 False
# 1757                       True  ...                 False
# 1758                       True  ...                 False
# 1759                       True  ...                 False
#
#       price_More than ₹400  beverage_type_Cold pressed juice  \
# 0                    False                              True
# 1                    False                              True
# 2                    False                              True
# 3                    False                              True
# 4                    False                              True
# ...                    ...                               ...
# 1755                 False                             False
# 1756                 False                             False
# 1757                 False                             False
# 1758                 False                              True
# 1759                 False                              True
#
#       beverage_type_Dairy based lassi or smoothies  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
# ...                                            ...
# 1755                                         False
# 1756                                          True
# 1757                                         False
# 1758                                         False
# 1759                                         False
#
#       beverage_type_Fusion of two or more fruits and nuts  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 1755                                              False
# 1756                                              False
# 1757                                               True
# 1758                                              False
# 1759                                              False
#
#       beverage_type_Healthy detox juice  beverage_type_Mocktails  \
# 0                                 False                    False
# 1                                 False                    False
# 2                                 False                    False
# 3                                 False                    False
# 4                                 False                    False
# ...                                 ...                      ...
# 1755                              False                     True
# 1756                              False                    False
# 1757                              False                    False
# 1758                              False                    False
# 1759                              False                    False
#
#       location_Equal preference  location_Food Court in malls  \
# 0                          True                         False
# 1                          True                         False
# 2                          True                         False
# 3                          True                         False
# 4                          True                         False
# ...                         ...                           ...
# 1755                      False                          True
# 1756                      False                          True
# 1757                      False                          True
# 1758                       True                         False
# 1759                      False                         False
#
#       location_Stand-alone outlets
# 0                            False
# 1                            False
# 2                            False
# 3                            False
# 4                            False
# ...                            ...
# 1755                         False
# 1756                         False
# 1757                         False
# 1758                         False
# 1759                          True
#
# [1760 rows x 21 columns]

# %%
# Write to folder
base_write_path = '../'
write_data_folder_name = 'src/datasets/'
write_filename = 'pre_launch_conjoint.csv'
conjoint_df.to_csv(path_or_buf= os.path.join(base_write_path, write_data_folder_name, write_filename), index = False)
