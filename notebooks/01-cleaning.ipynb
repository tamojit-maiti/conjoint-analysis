# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
# Import files
base_path = '../'
data_folder_name = 'data/raw/fresh-sip/'
survey_filename = 'Pre_Launch_Survey_Cleaned.csv'

# Input Data
survey_df = pd.read_csv(os.path.join(base_path, data_folder_name, survey_filename), index_col='Serial No')
survey_df
# Out:
#           What combination of ingredients present in a beverage are you more likely to buy?  \
# Serial No
# 1          Seasonal fruits such as mango, orange, grapes,...
# 2          Seasonal fruits such as mango, orange, grapes,...
# 3          Seasonal fruits such as mango, orange, grapes,...
# 4          Seasonal fruits such as mango, orange, grapes,...
# 5          Seasonal fruits such as mango, orange, grapes,...
# ...                                                      ...
# 106        Exotic Fruits such as kiwi, dragon fruit, blue...
# 107        Non seasonal fruits such as pineapple, apple, ...
# 108        Non seasonal fruits such as pineapple, apple, ...
# 109        Seasonal fruits such as mango, orange, grapes,...
# 110        Seasonal fruits such as mango, orange, grapes,...
#
#           What volume of beverage are you most likely to buy?  \
# Serial No
# 1                                                     500 ml
# 2                                                     350 ml
# 3                                           Less than 300 ml
# 4                                        Greater than 750 ml
# 5                                                     350 ml
# ...                                                      ...
# 106                                         Less than 300 ml
# 107                                         Less than 300 ml
# 108                                                   350 ml
# 109                                                   500 ml
# 110                                                   350 ml
#
#           At which price point are you most likely to buy a beverage?  \
# Serial No
# 1                                        Between ₹150 - ₹250
# 2                                        Between ₹150 - ₹250
# 3                                             Less than ₹150
# 4                                        Between ₹150 - ₹250
# 5                                             Less than ₹150
# ...                                                      ...
# 106                                      Between ₹150 - ₹250
# 107                                      Between ₹150 - ₹250
# 108                                           Less than ₹150
# 109                                           Less than ₹150
# 110                                      Between ₹150 - ₹250
#
#           Which beverage type appeals to you the most?  \
# Serial No
# 1                                   Cold pressed juice
# 2                                  Healthy detox juice
# 3                                   Cold pressed juice
# 4                                   Cold pressed juice
# 5                                   Cold pressed juice
# ...                                                ...
# 106              Fusion of two or more fruits and nuts
# 107              Fusion of two or more fruits and nuts
# 108                                 Cold pressed juice
# 109              Fusion of two or more fruits and nuts
# 110                                 Cold pressed juice
#
#           Which is your most preferred location to buy beverages?  \
# Serial No
# 1                                           Equal preference
# 2                                           Equal preference
# 3                                        Food Court in malls
# 4                                           Equal preference
# 5                                           Equal preference
# ...                                                      ...
# 106                                         Equal preference
# 107                                      Stand-alone outlets
# 108                                      Stand-alone outlets
# 109                                      Stand-alone outlets
# 110                                      Food Court in malls
#
#           Do you prefer to have juice during winters? If not, what is your preferred choice of drink during winters?
# Serial No
# 1                                                        NaN
# 2                                                        NaN
# 3                                                        NaN
# 4                                                        NaN
# 5                                                        NaN
# ...                                                      ...
# 106                                               No, coffee
# 107                                                      NaN
# 108                                                      NaN
# 109                                                      NaN
# 110                                                   Coffee
#
# [110 rows x 6 columns]

# %%
# Transform column names
survey_df.columns = ['ingredients','volume','price','beverage_type', 'location','response']
survey_df['response'] = 1
survey_df
# Out:
#                                                  ingredients  \
# Serial No
# 1          Seasonal fruits such as mango, orange, grapes,...
# 2          Seasonal fruits such as mango, orange, grapes,...
# 3          Seasonal fruits such as mango, orange, grapes,...
# 4          Seasonal fruits such as mango, orange, grapes,...
# 5          Seasonal fruits such as mango, orange, grapes,...
# ...                                                      ...
# 106        Exotic Fruits such as kiwi, dragon fruit, blue...
# 107        Non seasonal fruits such as pineapple, apple, ...
# 108        Non seasonal fruits such as pineapple, apple, ...
# 109        Seasonal fruits such as mango, orange, grapes,...
# 110        Seasonal fruits such as mango, orange, grapes,...
#
#                         volume                price  \
# Serial No
# 1                       500 ml  Between ₹150 - ₹250
# 2                       350 ml  Between ₹150 - ₹250
# 3             Less than 300 ml       Less than ₹150
# 4          Greater than 750 ml  Between ₹150 - ₹250
# 5                       350 ml       Less than ₹150
# ...                        ...                  ...
# 106           Less than 300 ml  Between ₹150 - ₹250
# 107           Less than 300 ml  Between ₹150 - ₹250
# 108                     350 ml       Less than ₹150
# 109                     500 ml       Less than ₹150
# 110                     350 ml  Between ₹150 - ₹250
#
#                                    beverage_type             location  \
# Serial No
# 1                             Cold pressed juice     Equal preference
# 2                            Healthy detox juice     Equal preference
# 3                             Cold pressed juice  Food Court in malls
# 4                             Cold pressed juice     Equal preference
# 5                             Cold pressed juice     Equal preference
# ...                                          ...                  ...
# 106        Fusion of two or more fruits and nuts     Equal preference
# 107        Fusion of two or more fruits and nuts  Stand-alone outlets
# 108                           Cold pressed juice  Stand-alone outlets
# 109        Fusion of two or more fruits and nuts  Stand-alone outlets
# 110                           Cold pressed juice  Food Court in malls
#
#            response
# Serial No
# 1                 1
# 2                 1
# 3                 1
# 4                 1
# 5                 1
# ...             ...
# 106               1
# 107               1
# 108               1
# 109               1
# 110               1
#
# [110 rows x 6 columns]

# %%
# Unique values per column
unique_vals = {}
columns = survey_df.columns
for col in survey_df.columns:
    unique_vals[col] = survey_df[col].unique().tolist()
unique_vals
# Out:
# {'ingredients': ['Seasonal fruits such as mango, orange, grapes, watermelon',
#   'Exotic Fruits such as kiwi, dragon fruit, blue berry',
#   'Non seasonal fruits such as pineapple, apple, banana, papaya',
#   'Veggies such as carrot, cucumber, tomato'],
#  'volume': ['500 ml', '350 ml', 'Less than 300 ml', 'Greater than 750 ml'],
#  'price': ['Between ₹150 - ₹250',
#   'Less than ₹150',
#   'More than ₹400',
#   'Between ₹250 - ₹400'],
#  'beverage_type': ['Cold pressed juice',
#   'Healthy detox juice',
#   'Mocktails',
#   'Dairy based lassi or smoothies',
#   'Fusion of two or more fruits and nuts'],
#  'location': ['Equal preference',
#   'Food Court in malls',
#   'Stand-alone outlets',
#   nan],
#  'response': [1]}

# %%
for index, row in survey_df.iloc[0:1,].iterrows():
    row_value = row.tolist()
    for col_index in range(5):
        col_row_value = row_value.copy()
        column = columns[col_index]
        value = row[col_index]
        unique_col_vals = unique_vals[column]
        unique_col_vals.remove(value)
        
        melt_row_value = [col_row_value] * len(unique_col_vals)
        for duplicate_row_index in range(1,len(melt_row_value)):
            duplicate_row = melt_row_value[duplicate_row_index]
            # set response equal to zero
            duplicate_row[-1] = 0
            # set new values to relevant column
            duplicate_row[col_index] = unique_col_vals[duplicate_row_index-1]

        print(melt_row_value)
# Out:
# C:\Users\tamoj\AppData\Local\Temp\ipykernel_2252\1586877121.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   value = row[col_index]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[58], line 11
#       8 unique_col_vals.remove(value)
#      10 melt_row_value = [col_row_value] * len(unique_col_vals)
# ---> 11 for duplicate_row_index in len(1,melt_row_value.shape[0]):
#      12     duplicate_row = melt_row_value[duplicate_row_index]
#      13     # set response equal to zero
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
a = [1,2,3]
a.remove(1)
a
# Out:
# [2, 3]
